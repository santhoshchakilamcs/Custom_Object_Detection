# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# %cd /gdrive/'My Drive'/object_detection
# Out:
# /gdrive/My Drive/object_detection

# %%
# !pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 39kB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.12.4)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.18.5)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 42.8MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 53.9MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 8.5MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.30.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.15) (49.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=66eb9a4c73f4dbb2a2f27bc11f542d0039fb661048f41013f7166cb841333186
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: gast, tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -qq Cython contextlib2 pillow lxml matplotlib pycocotools
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.1_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.3_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.3) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from __future__ import division, print_function, absolute_import

import pandas as pd
import numpy as np
import csv

import re
import os
import io
import glob
import shutil
import urllib.request
import tarfile
import xml.etree.ElementTree as ET

import tensorflow.compat.v1 as tf
import cv2 

from PIL import Image
from collections import namedtuple, OrderedDict

from google.colab import files

# %%
# %cd /gdrive/'My Drive'/object_detection/data/
# Out:
# /gdrive/My Drive/object_detection/data

# %%
def xml_to_csv(path):
  classes_names = []
  xml_list = []

  for xml_file in glob.glob(path + '/*.xml'):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
      classes_names.append(member[0].text)
      value = (root.find('filename').text + '.jpg',
               int(root.find('size')[0].text),
               int(root.find('size')[1].text),
               member[0].text,
               int(member[4][0].text),
               int(member[4][1].text),
               int(member[4][2].text),
               int(member[4][3].text))
      xml_list.append(value)
  column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
  xml_df = pd.DataFrame(xml_list, columns=column_name) 
  classes_names = list(set(classes_names))
  classes_names.sort()
  return xml_df, classes_names

for label_path in ['train_labels', 'test_labels']:
  image_path = os.path.join(os.getcwd(), label_path)
  xml_df, classes = xml_to_csv(label_path)
  xml_df.to_csv(f'{label_path}.csv', index=None)
  print(f'Successfully converted {label_path} xml to csv.')

label_map_path = os.path.join("label_map.pbtxt")
pbtxt_content = ""

for i, class_name in enumerate(classes):
    pbtxt_content = (
        pbtxt_content
        + "item {{\n    id: {0}\n    name: '{1}'\n}}\n\n".format(i + 1, class_name)
    )
pbtxt_content = pbtxt_content.strip()
with open(label_map_path, "w") as f:
    f.write(pbtxt_content)
# Out:
# Successfully converted train_labels xml to csv.
# Successfully converted test_labels xml to csv.

# %%
# %cd /gdrive/'My Drive'/object_detection
# Out:
# /gdrive/My Drive/object_detection

# %%
# !git clone --q https://github.com/tensorflow/models.git
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# %cd /gdrive/'My Drive'/object_detection/models/research
# Out:
# /gdrive/My Drive/object_detection/models/research

# %%
# compils the proto buffers
# !protoc object_detection/protos/*.proto --python_out=.
# exports PYTHONPATH environment var with research and slim paths
os.environ['PYTHONPATH'] += ':./:./slim/'

# %%
# !pip install tf_slim
# Out:
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from tf_slim) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)

# %%
# testing the model builder
# !python object_detection/builders/model_builder_test.py

# %%
from object_detection.utils import dataset_util


#change this to the base directory where your data/ is 
data_base_url = '/gdrive/My Drive/object_detection/data/'

#location of images
image_dir = data_base_url +'images/'

def class_text_to_int(row_label):
  if row_label == 'car':
    return 1
  elif row_label == 'wheel':
    return 2
  elif row_label == 'lugnuts':
    return 3    
  else:
    None

def split(df, group):
  data = namedtuple('data', ['filename', 'object'])
  gb = df.groupby(group)
  return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]

def create_tf_example(group, path):
	with tf.io.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
	  encoded_jpg = fid.read()
	encoded_jpg_io = io.BytesIO(encoded_jpg)
	image = Image.open(encoded_jpg_io)
	width, height = image.size
	filename = group.filename.encode('utf8')
	image_format = b'jpg'
	xmins = []
	xmaxs = []
	ymins = []
	ymaxs = []
	classes_text = []
	classes = []

	for index, row in group.object.iterrows():
		xmins.append(row['xmin'] / width)
		xmaxs.append(row['xmax'] / width)
		ymins.append(row['ymin'] / height)
		ymaxs.append(row['ymax'] / height)
		classes_text.append(row['class'].encode('utf8'))
		classes.append(class_text_to_int(row['class']))

	tf_example = tf.train.Example(features=tf.train.Features(feature={
		'image/height': dataset_util.int64_feature(height),
		'image/width': dataset_util.int64_feature(width),
		'image/filename': dataset_util.bytes_feature(filename),
		'image/source_id': dataset_util.bytes_feature(filename),
		'image/encoded': dataset_util.bytes_feature(encoded_jpg),
		'image/format': dataset_util.bytes_feature(image_format),
		'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
		'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
		'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
		'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
		'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
		'image/object/class/label': dataset_util.int64_list_feature(classes),
		}))
	return tf_example
#creates tfrecord for both csv's
for csv in ['train_labels', 'test_labels']:
  writer = tf.io.TFRecordWriter(data_base_url + csv + '.record')
  path = os.path.join(image_dir)
  examples = pd.read_csv(data_base_url + csv + '.csv')
  grouped = split(examples, 'filename')
  for group in grouped:
    
    tf_example = create_tf_example(group, path)
    writer.write(tf_example.SerializeToString())
    
  writer.close()
  output_path = os.path.join(os.getcwd(), data_base_url + csv + '.record')
  print('Successfully created the TFRecords: {}'.format(data_base_url +csv + '.record'))
# Out:
# Successfully created the TFRecords: /gdrive/My Drive/object_detection/data/train_labels.record
# Successfully created the TFRecords: /gdrive/My Drive/object_detection/data/test_labels.record

# %%
# Some models to train on
MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
    },
}

# Select a model from `MODELS_CONFIG`.
# I chose ssd_mobilenet_v2 for this project, you could choose any
selected_model = 'ssd_mobilenet_v2'

# %%
# %cd /gdrive/'My Drive'/object_detection/models/research
# Out:
# /gdrive/My Drive/object_detection/models/research

# %%
#the distination folder where the model will be saved
#change this if you have a different working dir
DEST_DIR = '/gdrive/My Drive/object_detection/models/research/pretrained_model'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

#selecting the model
MODEL_FILE = MODEL + '.tar.gz'

#creating the downlaod link for the model selected
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

#checks if the model has already been downloaded, download it otherwise
if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

#unzipping the model and extracting its content
tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

# creating an output file to save the model while training
os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)

# %%
#path to the config file
# !cat object_detection/samples/configs/ssd_mobilenet_v2_coco.config
# Out:
# model {
#   ssd {
#     num_classes: 3
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 300
#         width: 300
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 1
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               stddev: 0.03
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             train: true,
#             scale: true,
#             center: true,
#             decay: 0.9997,
#             epsilon: 0.001,
#           }
#         }
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2'
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             stddev: 0.03
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           train: true,
#           scale: true,
#           center: true,
#           decay: 0.9997,
#           epsilon: 0.001,
#         }
#       }
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid {
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       hard_example_miner {
#         num_hard_examples: 3000
#         iou_threshold: 0.99
#         loss_type: CLASSIFICATION
#         max_negatives_per_positive: 3
#         min_negatives_per_image: 3
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   batch_size: 3
#   optimizer {
#     rms_prop_optimizer: {
#       learning_rate: {
#         exponential_decay_learning_rate {
#           initial_learning_rate: 0.004
#           decay_steps: 800720
#           decay_factor: 0.95
#         }
#       }
#       momentum_optimizer_value: 0.9
#       decay: 0.9
#       epsilon: 1.0
#     }
#   }
#   fine_tune_checkpoint: "/gdrive/My Drive/object_detection/models/research/pretrained_model/model.ckpt"
#   fine_tune_checkpoint_type:  "detection"
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 200000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
# }
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/gdrive/My Drive/object_detection/data/train_labels.record"
#   }
#   label_map_path: "/gdrive/My Drive/object_detection/data/label_map.pbtxt"
# }
#
# eval_config: {
#   num_examples: 8000
#   # Note: The below line limits the evaluation process to 10 evaluations.
#   # Remove the below line to evaluate indefinitely.
#   max_evals: 10
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/gdrive/My Drive/object_detection/data/test_labels.record"
#   }
#   label_map_path: "/gdrive/My Drive/object_detection/data/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %%
#path to the config file
# %%writefile object_detection/samples/configs/ssd_mobilenet_v2_coco.config

model {
  ssd {
    num_classes: 3
    box_coder {
      faster_rcnn_box_coder {
        y_scale: 10.0
        x_scale: 10.0
        height_scale: 5.0
        width_scale: 5.0
      }
    }
    matcher {
      argmax_matcher {
        matched_threshold: 0.5
        unmatched_threshold: 0.5
        ignore_thresholds: false
        negatives_lower_than_unmatched: true
        force_match_for_each_row: true
      }
    }
    similarity_calculator {
      iou_similarity {
      }
    }
    anchor_generator {
      ssd_anchor_generator {
        num_layers: 6
        min_scale: 0.2
        max_scale: 0.95
        aspect_ratios: 1.0
        aspect_ratios: 2.0
        aspect_ratios: 0.5
        aspect_ratios: 3.0
        aspect_ratios: 0.3333
      }
    }
    image_resizer {
      fixed_shape_resizer {
        height: 300
        width: 300
      }
    }
    box_predictor {
      convolutional_box_predictor {
        min_depth: 0
        max_depth: 0
        num_layers_before_predictor: 0
        use_dropout: false
        dropout_keep_probability: 0.8
        kernel_size: 1
        box_code_size: 4
        apply_sigmoid_to_scores: false
        conv_hyperparams {
          activation: RELU_6,
          regularizer {
            l2_regularizer {
              weight: 0.00004
            }
          }
          initializer {
            truncated_normal_initializer {
              stddev: 0.03
              mean: 0.0
            }
          }
          batch_norm {
            train: true,
            scale: true,
            center: true,
            decay: 0.9997,
            epsilon: 0.001,
          }
        }
      }
    }
    feature_extractor {
      type: 'ssd_mobilenet_v2'
      min_depth: 16
      depth_multiplier: 1.0
      conv_hyperparams {
        activation: RELU_6,
        regularizer {
          l2_regularizer {
            weight: 0.00004
          }
        }
        initializer {
          truncated_normal_initializer {
            stddev: 0.03
            mean: 0.0
          }
        }
        batch_norm {
          train: true,
          scale: true,
          center: true,
          decay: 0.9997,
          epsilon: 0.001,
        }
      }
    }
    loss {
      classification_loss {
        weighted_sigmoid {
        }
      }
      localization_loss {
        weighted_smooth_l1 {
        }
      }
      hard_example_miner {
        num_hard_examples: 3000
        iou_threshold: 0.99
        loss_type: CLASSIFICATION
        max_negatives_per_positive: 3
        min_negatives_per_image: 3
      }
      classification_weight: 1.0
      localization_weight: 1.0
    }
    normalize_loss_by_num_matches: true
    post_processing {
      batch_non_max_suppression {
        score_threshold: 1e-8
        iou_threshold: 0.6
        max_detections_per_class: 100
        max_total_detections: 100
      }
      score_converter: SIGMOID
    }
  }
}

train_config: {
  batch_size: 3
  optimizer {
    rms_prop_optimizer: {
      learning_rate: {
        exponential_decay_learning_rate {
          initial_learning_rate: 0.004
          decay_steps: 800720
          decay_factor: 0.95
        }
      }
      momentum_optimizer_value: 0.9
      decay: 0.9
      epsilon: 1.0
    }
  }
  fine_tune_checkpoint: "/gdrive/My Drive/object_detection/models/research/pretrained_model/model.ckpt"
  fine_tune_checkpoint_type:  "detection"
  # Note: The below line limits the training process to 200K steps, which we
  # empirically found to be sufficient enough to train the pets dataset. This
  # effectively bypasses the learning rate schedule (the learning rate will
  # never decay). Remove the below line to train indefinitely.
  num_steps: 200000
  data_augmentation_options {
    random_horizontal_flip {
    }
  }
  data_augmentation_options {
    ssd_random_crop {
    }
  }
}

train_input_reader: {
  tf_record_input_reader {
    input_path: "/gdrive/My Drive/object_detection/data/train_labels.record"
  }
  label_map_path: "/gdrive/My Drive/object_detection/data/label_map.pbtxt"
}

eval_config: {
  num_examples: 8000
  # Note: The below line limits the evaluation process to 10 evaluations.
  # Remove the below line to evaluate indefinitely.
  max_evals: 10
}

eval_input_reader: {
  tf_record_input_reader {
    input_path: "/gdrive/My Drive/object_detection/data/test_labels.record"
  }
  label_map_path: "/gdrive/My Drive/object_detection/data/label_map.pbtxt"
  shuffle: false
  num_readers: 1
}
# Out:
# Overwriting object_detection/samples/configs/ssd_mobilenet_v2_coco.config

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2020-08-10 01:06:29--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.88.63.64, 18.208.90.15, 3.233.171.45, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.88.63.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  17.0MB/s    in 0.8s
#
# 2020-08-10 01:06:30 (17.0 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
#the logs that are created while training 
LOG_DIR = "training/"
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
#The link to tensorboard.
#works after the training starts.
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://1b805ed2aa17.ngrok.io

# %%
# !python object_detection/model_main.py \
    --pipeline_config_path=/gdrive/My\ Drive/object_detection/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config \
    --model_dir=training/
# Out:
# Streaming output truncated to the last 5000 lines.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0810 01:19:55.148747 140156632352512 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0810 01:19:55.149372 140156632352512 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.070
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.184
# INFO:tensorflow:Finished evaluation at 2020-08-10-01:19:56
# I0810 01:19:56.037562 140158977697664 evaluation.py:275] Finished evaluation at 2020-08-10-01:19:56
# INFO:tensorflow:Saving dict for global step 8000: DetectionBoxes_Precision/mAP = 0.069586806, DetectionBoxes_Precision/mAP (large) = 0.09523417, DetectionBoxes_Precision/mAP (medium) = 0.042079207, DetectionBoxes_Precision/mAP (small) = 0.0, DetectionBoxes_Precision/mAP@.50IOU = 0.2787158, DetectionBoxes_Precision/mAP@.75IOU = 0.028571429, DetectionBoxes_Recall/AR@1 = 0.095, DetectionBoxes_Recall/AR@10 = 0.10666667, DetectionBoxes_Recall/AR@100 = 0.14333333, DetectionBoxes_Recall/AR@100 (large) = 0.18375, DetectionBoxes_Recall/AR@100 (medium) = 0.05, DetectionBoxes_Recall/AR@100 (small) = 0.0, Loss/classification_loss = 11.835447, Loss/localization_loss = 3.155172, Loss/regularization_loss = 0.33149853, Loss/total_loss = 15.322118, global_step = 8000, learning_rate = 0.004, loss = 15.322118
# I0810 01:19:56.037915 140158977697664 estimator.py:2049] Saving dict for global step 8000: DetectionBoxes_Precision/mAP = 0.069586806, DetectionBoxes_Precision/mAP (large) = 0.09523417, DetectionBoxes_Precision/mAP (medium) = 0.042079207, DetectionBoxes_Precision/mAP (small) = 0.0, DetectionBoxes_Precision/mAP@.50IOU = 0.2787158, DetectionBoxes_Precision/mAP@.75IOU = 0.028571429, DetectionBoxes_Recall/AR@1 = 0.095, DetectionBoxes_Recall/AR@10 = 0.10666667, DetectionBoxes_Recall/AR@100 = 0.14333333, DetectionBoxes_Recall/AR@100 (large) = 0.18375, DetectionBoxes_Recall/AR@100 (medium) = 0.05, DetectionBoxes_Recall/AR@100 (small) = 0.0, Loss/classification_loss = 11.835447, Loss/localization_loss = 3.155172, Loss/regularization_loss = 0.33149853, Loss/total_loss = 15.322118, global_step = 8000, learning_rate = 0.004, loss = 15.322118
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: training/model.ckpt-8000
# I0810 01:19:56.784936 140158977697664 estimator.py:2109] Saving 'checkpoint_path' summary for global step 8000: training/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 5.24621
# I0810 01:19:56.910857 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 5.24621
# INFO:tensorflow:loss = 3.6701603, step = 8000 (19.061 sec)
# I0810 01:19:56.911838 140158977697664 basic_session_run_hooks.py:260] loss = 3.6701603, step = 8000 (19.061 sec)
# INFO:tensorflow:global_step/sec: 13.7272
# I0810 01:20:04.195692 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7272
# INFO:tensorflow:loss = 2.62405, step = 8100 (7.285 sec)
# I0810 01:20:04.196584 140158977697664 basic_session_run_hooks.py:260] loss = 2.62405, step = 8100 (7.285 sec)
# INFO:tensorflow:global_step/sec: 13.6058
# I0810 01:20:11.545496 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6058
# INFO:tensorflow:loss = 1.4425807, step = 8200 (7.350 sec)
# I0810 01:20:11.546676 140158977697664 basic_session_run_hooks.py:260] loss = 1.4425807, step = 8200 (7.350 sec)
# INFO:tensorflow:global_step/sec: 13.4278
# I0810 01:20:18.992726 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4278
# INFO:tensorflow:loss = 4.7754183, step = 8300 (7.447 sec)
# I0810 01:20:18.993702 140158977697664 basic_session_run_hooks.py:260] loss = 4.7754183, step = 8300 (7.447 sec)
# INFO:tensorflow:global_step/sec: 13.4303
# I0810 01:20:26.438556 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4303
# INFO:tensorflow:loss = 3.1296384, step = 8400 (7.446 sec)
# I0810 01:20:26.439723 140158977697664 basic_session_run_hooks.py:260] loss = 3.1296384, step = 8400 (7.446 sec)
# INFO:tensorflow:global_step/sec: 13.5929
# I0810 01:20:33.795325 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5929
# INFO:tensorflow:loss = 4.5524697, step = 8500 (7.357 sec)
# I0810 01:20:33.796294 140158977697664 basic_session_run_hooks.py:260] loss = 4.5524697, step = 8500 (7.357 sec)
# INFO:tensorflow:global_step/sec: 13.5131
# I0810 01:20:41.195617 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5131
# INFO:tensorflow:loss = 3.690609, step = 8600 (7.400 sec)
# I0810 01:20:41.196502 140158977697664 basic_session_run_hooks.py:260] loss = 3.690609, step = 8600 (7.400 sec)
# INFO:tensorflow:global_step/sec: 14.0372
# I0810 01:20:48.319508 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0372
# INFO:tensorflow:loss = 2.1918156, step = 8700 (7.124 sec)
# I0810 01:20:48.320657 140158977697664 basic_session_run_hooks.py:260] loss = 2.1918156, step = 8700 (7.124 sec)
# INFO:tensorflow:global_step/sec: 13.7765
# I0810 01:20:55.578231 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7765
# INFO:tensorflow:loss = 3.4582517, step = 8800 (7.258 sec)
# I0810 01:20:55.579112 140158977697664 basic_session_run_hooks.py:260] loss = 3.4582517, step = 8800 (7.258 sec)
# INFO:tensorflow:global_step/sec: 13.9939
# I0810 01:21:02.724198 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9939
# INFO:tensorflow:loss = 3.4295654, step = 8900 (7.147 sec)
# I0810 01:21:02.725846 140158977697664 basic_session_run_hooks.py:260] loss = 3.4295654, step = 8900 (7.147 sec)
# INFO:tensorflow:global_step/sec: 14.0026
# I0810 01:21:09.865763 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0026
# INFO:tensorflow:loss = 4.576105, step = 9000 (7.141 sec)
# I0810 01:21:09.866821 140158977697664 basic_session_run_hooks.py:260] loss = 4.576105, step = 9000 (7.141 sec)
# INFO:tensorflow:global_step/sec: 13.3732
# I0810 01:21:17.343396 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3732
# INFO:tensorflow:loss = 2.9411423, step = 9100 (7.478 sec)
# I0810 01:21:17.344464 140158977697664 basic_session_run_hooks.py:260] loss = 2.9411423, step = 9100 (7.478 sec)
# INFO:tensorflow:global_step/sec: 13.4528
# I0810 01:21:24.776827 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4528
# INFO:tensorflow:loss = 4.4275565, step = 9200 (7.433 sec)
# I0810 01:21:24.777961 140158977697664 basic_session_run_hooks.py:260] loss = 4.4275565, step = 9200 (7.433 sec)
# INFO:tensorflow:global_step/sec: 13.6413
# I0810 01:21:32.107508 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6413
# INFO:tensorflow:loss = 2.5997205, step = 9300 (7.331 sec)
# I0810 01:21:32.108621 140158977697664 basic_session_run_hooks.py:260] loss = 2.5997205, step = 9300 (7.331 sec)
# INFO:tensorflow:global_step/sec: 13.5694
# I0810 01:21:39.477058 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5694
# INFO:tensorflow:loss = 4.891609, step = 9400 (7.370 sec)
# I0810 01:21:39.478267 140158977697664 basic_session_run_hooks.py:260] loss = 4.891609, step = 9400 (7.370 sec)
# INFO:tensorflow:global_step/sec: 13.722
# I0810 01:21:46.764612 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.722
# INFO:tensorflow:loss = 1.7680216, step = 9500 (7.288 sec)
# I0810 01:21:46.765867 140158977697664 basic_session_run_hooks.py:260] loss = 1.7680216, step = 9500 (7.288 sec)
# INFO:tensorflow:global_step/sec: 14.017
# I0810 01:21:53.898794 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.017
# INFO:tensorflow:loss = 1.4943064, step = 9600 (7.134 sec)
# I0810 01:21:53.899847 140158977697664 basic_session_run_hooks.py:260] loss = 1.4943064, step = 9600 (7.134 sec)
# INFO:tensorflow:global_step/sec: 13.8261
# I0810 01:22:01.131484 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8261
# INFO:tensorflow:loss = 2.7070186, step = 9700 (7.233 sec)
# I0810 01:22:01.132673 140158977697664 basic_session_run_hooks.py:260] loss = 2.7070186, step = 9700 (7.233 sec)
# INFO:tensorflow:global_step/sec: 13.6018
# I0810 01:22:08.483453 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6018
# INFO:tensorflow:loss = 3.5019727, step = 9800 (7.352 sec)
# I0810 01:22:08.484537 140158977697664 basic_session_run_hooks.py:260] loss = 3.5019727, step = 9800 (7.352 sec)
# INFO:tensorflow:global_step/sec: 13.9103
# I0810 01:22:15.672388 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9103
# INFO:tensorflow:loss = 5.9658346, step = 9900 (7.189 sec)
# I0810 01:22:15.673339 140158977697664 basic_session_run_hooks.py:260] loss = 5.9658346, step = 9900 (7.189 sec)
# INFO:tensorflow:global_step/sec: 13.5062
# I0810 01:22:23.076389 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5062
# INFO:tensorflow:loss = 3.9113204, step = 10000 (7.404 sec)
# I0810 01:22:23.077553 140158977697664 basic_session_run_hooks.py:260] loss = 3.9113204, step = 10000 (7.404 sec)
# INFO:tensorflow:global_step/sec: 12.8995
# I0810 01:22:30.828646 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 12.8995
# INFO:tensorflow:loss = 1.8772295, step = 10100 (7.752 sec)
# I0810 01:22:30.829921 140158977697664 basic_session_run_hooks.py:260] loss = 1.8772295, step = 10100 (7.752 sec)
# INFO:tensorflow:global_step/sec: 13.6481
# I0810 01:22:38.155673 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6481
# INFO:tensorflow:loss = 2.5454931, step = 10200 (7.327 sec)
# I0810 01:22:38.156617 140158977697664 basic_session_run_hooks.py:260] loss = 2.5454931, step = 10200 (7.327 sec)
# INFO:tensorflow:global_step/sec: 13.7385
# I0810 01:22:45.434498 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7385
# INFO:tensorflow:loss = 3.3334012, step = 10300 (7.279 sec)
# I0810 01:22:45.435459 140158977697664 basic_session_run_hooks.py:260] loss = 3.3334012, step = 10300 (7.279 sec)
# INFO:tensorflow:global_step/sec: 13.5981
# I0810 01:22:52.788443 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5981
# INFO:tensorflow:loss = 1.7345912, step = 10400 (7.354 sec)
# I0810 01:22:52.789388 140158977697664 basic_session_run_hooks.py:260] loss = 1.7345912, step = 10400 (7.354 sec)
# INFO:tensorflow:global_step/sec: 13.3086
# I0810 01:23:00.302349 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3086
# INFO:tensorflow:loss = 3.5153787, step = 10500 (7.514 sec)
# I0810 01:23:00.303452 140158977697664 basic_session_run_hooks.py:260] loss = 3.5153787, step = 10500 (7.514 sec)
# INFO:tensorflow:global_step/sec: 13.6387
# I0810 01:23:07.634430 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6387
# INFO:tensorflow:loss = 2.342362, step = 10600 (7.332 sec)
# I0810 01:23:07.635349 140158977697664 basic_session_run_hooks.py:260] loss = 2.342362, step = 10600 (7.332 sec)
# INFO:tensorflow:global_step/sec: 13.7747
# I0810 01:23:14.894101 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7747
# INFO:tensorflow:loss = 2.5554106, step = 10700 (7.260 sec)
# I0810 01:23:14.895108 140158977697664 basic_session_run_hooks.py:260] loss = 2.5554106, step = 10700 (7.260 sec)
# INFO:tensorflow:global_step/sec: 13.4326
# I0810 01:23:22.338687 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4326
# INFO:tensorflow:loss = 3.32776, step = 10800 (7.445 sec)
# I0810 01:23:22.339922 140158977697664 basic_session_run_hooks.py:260] loss = 3.32776, step = 10800 (7.445 sec)
# INFO:tensorflow:global_step/sec: 13.5872
# I0810 01:23:29.698529 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5872
# INFO:tensorflow:loss = 4.0647483, step = 10900 (7.360 sec)
# I0810 01:23:29.699577 140158977697664 basic_session_run_hooks.py:260] loss = 4.0647483, step = 10900 (7.360 sec)
# INFO:tensorflow:global_step/sec: 13.9287
# I0810 01:23:36.877960 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9287
# INFO:tensorflow:loss = 2.3605921, step = 11000 (7.179 sec)
# I0810 01:23:36.878938 140158977697664 basic_session_run_hooks.py:260] loss = 2.3605921, step = 11000 (7.179 sec)
# INFO:tensorflow:global_step/sec: 13.6685
# I0810 01:23:44.194048 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6685
# INFO:tensorflow:loss = 3.2074537, step = 11100 (7.316 sec)
# I0810 01:23:44.194991 140158977697664 basic_session_run_hooks.py:260] loss = 3.2074537, step = 11100 (7.316 sec)
# INFO:tensorflow:global_step/sec: 14.0356
# I0810 01:23:51.318795 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0356
# INFO:tensorflow:loss = 3.407158, step = 11200 (7.125 sec)
# I0810 01:23:51.320431 140158977697664 basic_session_run_hooks.py:260] loss = 3.407158, step = 11200 (7.125 sec)
# INFO:tensorflow:global_step/sec: 13.5903
# I0810 01:23:58.676996 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5903
# INFO:tensorflow:loss = 1.7972537, step = 11300 (7.358 sec)
# I0810 01:23:58.678003 140158977697664 basic_session_run_hooks.py:260] loss = 1.7972537, step = 11300 (7.358 sec)
# INFO:tensorflow:global_step/sec: 13.6152
# I0810 01:24:06.021755 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6152
# INFO:tensorflow:loss = 4.4465036, step = 11400 (7.345 sec)
# I0810 01:24:06.022932 140158977697664 basic_session_run_hooks.py:260] loss = 4.4465036, step = 11400 (7.345 sec)
# INFO:tensorflow:global_step/sec: 13.4707
# I0810 01:24:13.445254 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4707
# INFO:tensorflow:loss = 2.9819272, step = 11500 (7.423 sec)
# I0810 01:24:13.446217 140158977697664 basic_session_run_hooks.py:260] loss = 2.9819272, step = 11500 (7.423 sec)
# INFO:tensorflow:global_step/sec: 13.5009
# I0810 01:24:20.852193 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5009
# INFO:tensorflow:loss = 1.9044294, step = 11600 (7.407 sec)
# I0810 01:24:20.853254 140158977697664 basic_session_run_hooks.py:260] loss = 1.9044294, step = 11600 (7.407 sec)
# INFO:tensorflow:global_step/sec: 13.5955
# I0810 01:24:28.207558 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5955
# INFO:tensorflow:loss = 2.1405208, step = 11700 (7.355 sec)
# I0810 01:24:28.208734 140158977697664 basic_session_run_hooks.py:260] loss = 2.1405208, step = 11700 (7.355 sec)
# INFO:tensorflow:global_step/sec: 13.9204
# I0810 01:24:35.391247 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9204
# INFO:tensorflow:loss = 2.8052552, step = 11800 (7.184 sec)
# I0810 01:24:35.392277 140158977697664 basic_session_run_hooks.py:260] loss = 2.8052552, step = 11800 (7.184 sec)
# INFO:tensorflow:global_step/sec: 13.7415
# I0810 01:24:42.668486 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7415
# INFO:tensorflow:loss = 2.0164902, step = 11900 (7.277 sec)
# I0810 01:24:42.669498 140158977697664 basic_session_run_hooks.py:260] loss = 2.0164902, step = 11900 (7.277 sec)
# INFO:tensorflow:global_step/sec: 13.3036
# I0810 01:24:50.185243 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3036
# INFO:tensorflow:loss = 2.405202, step = 12000 (7.517 sec)
# I0810 01:24:50.186167 140158977697664 basic_session_run_hooks.py:260] loss = 2.405202, step = 12000 (7.517 sec)
# INFO:tensorflow:global_step/sec: 13.5148
# I0810 01:24:57.584557 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5148
# INFO:tensorflow:loss = 2.5828054, step = 12100 (7.399 sec)
# I0810 01:24:57.585662 140158977697664 basic_session_run_hooks.py:260] loss = 2.5828054, step = 12100 (7.399 sec)
# INFO:tensorflow:global_step/sec: 13.647
# I0810 01:25:04.912149 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.647
# INFO:tensorflow:loss = 3.8184564, step = 12200 (7.327 sec)
# I0810 01:25:04.913039 140158977697664 basic_session_run_hooks.py:260] loss = 3.8184564, step = 12200 (7.327 sec)
# INFO:tensorflow:global_step/sec: 13.6027
# I0810 01:25:12.263654 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6027
# INFO:tensorflow:loss = 1.9306214, step = 12300 (7.352 sec)
# I0810 01:25:12.264725 140158977697664 basic_session_run_hooks.py:260] loss = 1.9306214, step = 12300 (7.352 sec)
# INFO:tensorflow:global_step/sec: 13.7053
# I0810 01:25:19.560095 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7053
# INFO:tensorflow:loss = 2.6192138, step = 12400 (7.296 sec)
# I0810 01:25:19.561037 140158977697664 basic_session_run_hooks.py:260] loss = 2.6192138, step = 12400 (7.296 sec)
# INFO:tensorflow:global_step/sec: 13.4967
# I0810 01:25:26.969317 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4967
# INFO:tensorflow:loss = 3.2857327, step = 12500 (7.409 sec)
# I0810 01:25:26.970479 140158977697664 basic_session_run_hooks.py:260] loss = 3.2857327, step = 12500 (7.409 sec)
# INFO:tensorflow:global_step/sec: 13.4964
# I0810 01:25:34.378708 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4964
# INFO:tensorflow:loss = 4.0148044, step = 12600 (7.409 sec)
# I0810 01:25:34.379539 140158977697664 basic_session_run_hooks.py:260] loss = 4.0148044, step = 12600 (7.409 sec)
# INFO:tensorflow:global_step/sec: 13.665
# I0810 01:25:41.696722 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.665
# INFO:tensorflow:loss = 2.3508706, step = 12700 (7.318 sec)
# I0810 01:25:41.697554 140158977697664 basic_session_run_hooks.py:260] loss = 2.3508706, step = 12700 (7.318 sec)
# INFO:tensorflow:global_step/sec: 13.7514
# I0810 01:25:48.968685 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7514
# INFO:tensorflow:loss = 1.4254656, step = 12800 (7.272 sec)
# I0810 01:25:48.969833 140158977697664 basic_session_run_hooks.py:260] loss = 1.4254656, step = 12800 (7.272 sec)
# INFO:tensorflow:global_step/sec: 13.4764
# I0810 01:25:56.389031 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4764
# INFO:tensorflow:loss = 2.1387753, step = 12900 (7.421 sec)
# I0810 01:25:56.390435 140158977697664 basic_session_run_hooks.py:260] loss = 2.1387753, step = 12900 (7.421 sec)
# INFO:tensorflow:global_step/sec: 13.4476
# I0810 01:26:03.825277 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4476
# INFO:tensorflow:loss = 3.576473, step = 13000 (7.436 sec)
# I0810 01:26:03.826418 140158977697664 basic_session_run_hooks.py:260] loss = 3.576473, step = 13000 (7.436 sec)
# INFO:tensorflow:global_step/sec: 13.0046
# I0810 01:26:11.514843 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.0046
# INFO:tensorflow:loss = 2.648293, step = 13100 (7.690 sec)
# I0810 01:26:11.515930 140158977697664 basic_session_run_hooks.py:260] loss = 2.648293, step = 13100 (7.690 sec)
# INFO:tensorflow:global_step/sec: 13.527
# I0810 01:26:18.907430 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.527
# INFO:tensorflow:loss = 3.0888922, step = 13200 (7.393 sec)
# I0810 01:26:18.908581 140158977697664 basic_session_run_hooks.py:260] loss = 3.0888922, step = 13200 (7.393 sec)
# INFO:tensorflow:global_step/sec: 13.5564
# I0810 01:26:26.284019 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5564
# INFO:tensorflow:loss = 1.7172263, step = 13300 (7.377 sec)
# I0810 01:26:26.285124 140158977697664 basic_session_run_hooks.py:260] loss = 1.7172263, step = 13300 (7.377 sec)
# INFO:tensorflow:global_step/sec: 13.6165
# I0810 01:26:33.628064 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6165
# INFO:tensorflow:loss = 1.6322004, step = 13400 (7.344 sec)
# I0810 01:26:33.629076 140158977697664 basic_session_run_hooks.py:260] loss = 1.6322004, step = 13400 (7.344 sec)
# INFO:tensorflow:global_step/sec: 13.5553
# I0810 01:26:41.005259 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5553
# INFO:tensorflow:loss = 1.5326554, step = 13500 (7.377 sec)
# I0810 01:26:41.006481 140158977697664 basic_session_run_hooks.py:260] loss = 1.5326554, step = 13500 (7.377 sec)
# INFO:tensorflow:global_step/sec: 13.6788
# I0810 01:26:48.315822 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6788
# INFO:tensorflow:loss = 3.5757926, step = 13600 (7.310 sec)
# I0810 01:26:48.316746 140158977697664 basic_session_run_hooks.py:260] loss = 3.5757926, step = 13600 (7.310 sec)
# INFO:tensorflow:global_step/sec: 13.3176
# I0810 01:26:55.824696 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3176
# INFO:tensorflow:loss = 2.029953, step = 13700 (7.509 sec)
# I0810 01:26:55.825791 140158977697664 basic_session_run_hooks.py:260] loss = 2.029953, step = 13700 (7.509 sec)
# INFO:tensorflow:global_step/sec: 13.255
# I0810 01:27:03.368962 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.255
# INFO:tensorflow:loss = 2.9141645, step = 13800 (7.544 sec)
# I0810 01:27:03.370099 140158977697664 basic_session_run_hooks.py:260] loss = 2.9141645, step = 13800 (7.544 sec)
# INFO:tensorflow:global_step/sec: 13.6474
# I0810 01:27:10.696381 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6474
# INFO:tensorflow:loss = 2.4113352, step = 13900 (7.327 sec)
# I0810 01:27:10.697494 140158977697664 basic_session_run_hooks.py:260] loss = 2.4113352, step = 13900 (7.327 sec)
# INFO:tensorflow:global_step/sec: 13.6486
# I0810 01:27:18.023126 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6486
# INFO:tensorflow:loss = 3.0030317, step = 14000 (7.327 sec)
# I0810 01:27:18.024178 140158977697664 basic_session_run_hooks.py:260] loss = 3.0030317, step = 14000 (7.327 sec)
# INFO:tensorflow:global_step/sec: 13.6439
# I0810 01:27:25.352427 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6439
# INFO:tensorflow:loss = 3.0509498, step = 14100 (7.329 sec)
# I0810 01:27:25.353486 140158977697664 basic_session_run_hooks.py:260] loss = 3.0509498, step = 14100 (7.329 sec)
# INFO:tensorflow:global_step/sec: 13.8858
# I0810 01:27:32.554035 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8858
# INFO:tensorflow:loss = 1.5065088, step = 14200 (7.202 sec)
# I0810 01:27:32.555076 140158977697664 basic_session_run_hooks.py:260] loss = 1.5065088, step = 14200 (7.202 sec)
# INFO:tensorflow:global_step/sec: 13.8415
# I0810 01:27:39.778676 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8415
# INFO:tensorflow:loss = 4.433363, step = 14300 (7.224 sec)
# I0810 01:27:39.779544 140158977697664 basic_session_run_hooks.py:260] loss = 4.433363, step = 14300 (7.224 sec)
# INFO:tensorflow:global_step/sec: 13.7576
# I0810 01:27:47.047362 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7576
# INFO:tensorflow:loss = 2.6960676, step = 14400 (7.269 sec)
# I0810 01:27:47.048310 140158977697664 basic_session_run_hooks.py:260] loss = 2.6960676, step = 14400 (7.269 sec)
# INFO:tensorflow:global_step/sec: 13.7895
# I0810 01:27:54.299273 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7895
# INFO:tensorflow:loss = 1.821208, step = 14500 (7.252 sec)
# I0810 01:27:54.300370 140158977697664 basic_session_run_hooks.py:260] loss = 1.821208, step = 14500 (7.252 sec)
# INFO:tensorflow:global_step/sec: 13.9867
# I0810 01:28:01.448908 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9867
# INFO:tensorflow:loss = 3.138556, step = 14600 (7.150 sec)
# I0810 01:28:01.450514 140158977697664 basic_session_run_hooks.py:260] loss = 3.138556, step = 14600 (7.150 sec)
# INFO:tensorflow:global_step/sec: 13.9868
# I0810 01:28:08.598471 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9868
# INFO:tensorflow:loss = 2.9516726, step = 14700 (7.149 sec)
# I0810 01:28:08.599887 140158977697664 basic_session_run_hooks.py:260] loss = 2.9516726, step = 14700 (7.149 sec)
# INFO:tensorflow:global_step/sec: 13.0119
# I0810 01:28:16.283771 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.0119
# INFO:tensorflow:loss = 2.924159, step = 14800 (7.685 sec)
# I0810 01:28:16.284936 140158977697664 basic_session_run_hooks.py:260] loss = 2.924159, step = 14800 (7.685 sec)
# INFO:tensorflow:global_step/sec: 13.3249
# I0810 01:28:23.788498 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3249
# INFO:tensorflow:loss = 3.2527375, step = 14900 (7.505 sec)
# I0810 01:28:23.789580 140158977697664 basic_session_run_hooks.py:260] loss = 3.2527375, step = 14900 (7.505 sec)
# INFO:tensorflow:global_step/sec: 13.9698
# I0810 01:28:30.946812 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9698
# INFO:tensorflow:loss = 2.5831454, step = 15000 (7.158 sec)
# I0810 01:28:30.947893 140158977697664 basic_session_run_hooks.py:260] loss = 2.5831454, step = 15000 (7.158 sec)
# INFO:tensorflow:global_step/sec: 13.7555
# I0810 01:28:38.216621 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7555
# INFO:tensorflow:loss = 2.1674492, step = 15100 (7.270 sec)
# I0810 01:28:38.217636 140158977697664 basic_session_run_hooks.py:260] loss = 2.1674492, step = 15100 (7.270 sec)
# INFO:tensorflow:global_step/sec: 13.6198
# I0810 01:28:45.558843 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6198
# INFO:tensorflow:loss = 2.8851905, step = 15200 (7.342 sec)
# I0810 01:28:45.559799 140158977697664 basic_session_run_hooks.py:260] loss = 2.8851905, step = 15200 (7.342 sec)
# INFO:tensorflow:global_step/sec: 14.0659
# I0810 01:28:52.668215 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0659
# INFO:tensorflow:loss = 2.755614, step = 15300 (7.110 sec)
# I0810 01:28:52.669321 140158977697664 basic_session_run_hooks.py:260] loss = 2.755614, step = 15300 (7.110 sec)
# INFO:tensorflow:global_step/sec: 13.1857
# I0810 01:29:00.252196 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1857
# INFO:tensorflow:loss = 3.5786917, step = 15400 (7.584 sec)
# I0810 01:29:00.253251 140158977697664 basic_session_run_hooks.py:260] loss = 3.5786917, step = 15400 (7.584 sec)
# INFO:tensorflow:global_step/sec: 13.1368
# I0810 01:29:07.864413 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1368
# INFO:tensorflow:loss = 2.35006, step = 15500 (7.612 sec)
# I0810 01:29:07.865403 140158977697664 basic_session_run_hooks.py:260] loss = 2.35006, step = 15500 (7.612 sec)
# INFO:tensorflow:global_step/sec: 13.7416
# I0810 01:29:15.141606 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7416
# INFO:tensorflow:loss = 2.3069568, step = 15600 (7.277 sec)
# I0810 01:29:15.142768 140158977697664 basic_session_run_hooks.py:260] loss = 2.3069568, step = 15600 (7.277 sec)
# INFO:tensorflow:global_step/sec: 13.5621
# I0810 01:29:22.515078 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5621
# INFO:tensorflow:loss = 2.4696727, step = 15700 (7.373 sec)
# I0810 01:29:22.516211 140158977697664 basic_session_run_hooks.py:260] loss = 2.4696727, step = 15700 (7.373 sec)
# INFO:tensorflow:global_step/sec: 13.9167
# I0810 01:29:29.700711 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9167
# INFO:tensorflow:loss = 3.1128247, step = 15800 (7.186 sec)
# I0810 01:29:29.701825 140158977697664 basic_session_run_hooks.py:260] loss = 3.1128247, step = 15800 (7.186 sec)
# INFO:tensorflow:global_step/sec: 13.6284
# I0810 01:29:37.038289 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6284
# INFO:tensorflow:loss = 2.742639, step = 15900 (7.338 sec)
# I0810 01:29:37.039405 140158977697664 basic_session_run_hooks.py:260] loss = 2.742639, step = 15900 (7.338 sec)
# INFO:tensorflow:global_step/sec: 13.7992
# I0810 01:29:44.285122 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7992
# INFO:tensorflow:loss = 3.5407782, step = 16000 (7.247 sec)
# I0810 01:29:44.286381 140158977697664 basic_session_run_hooks.py:260] loss = 3.5407782, step = 16000 (7.247 sec)
# INFO:tensorflow:Saving checkpoints for 16011 into training/model.ckpt.
# I0810 01:29:45.006282 140158977697664 basic_session_run_hooks.py:606] Saving checkpoints for 16011 into training/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (600 secs).
# I0810 01:29:46.190813 140158977697664 training.py:527] Skip the current checkpoint eval due to throttle secs (600 secs).
# INFO:tensorflow:global_step/sec: 11.5455
# I0810 01:29:52.946489 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 11.5455
# INFO:tensorflow:loss = 2.6291316, step = 16100 (8.661 sec)
# I0810 01:29:52.947332 140158977697664 basic_session_run_hooks.py:260] loss = 2.6291316, step = 16100 (8.661 sec)
# INFO:tensorflow:global_step/sec: 13.9952
# I0810 01:30:00.091782 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9952
# INFO:tensorflow:loss = 4.9929953, step = 16200 (7.146 sec)
# I0810 01:30:00.093207 140158977697664 basic_session_run_hooks.py:260] loss = 4.9929953, step = 16200 (7.146 sec)
# INFO:tensorflow:global_step/sec: 13.9578
# I0810 01:30:07.256237 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9578
# INFO:tensorflow:loss = 1.7364411, step = 16300 (7.165 sec)
# I0810 01:30:07.258379 140158977697664 basic_session_run_hooks.py:260] loss = 1.7364411, step = 16300 (7.165 sec)
# INFO:tensorflow:global_step/sec: 13.3029
# I0810 01:30:14.773403 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3029
# INFO:tensorflow:loss = 2.304412, step = 16400 (7.516 sec)
# I0810 01:30:14.774560 140158977697664 basic_session_run_hooks.py:260] loss = 2.304412, step = 16400 (7.516 sec)
# INFO:tensorflow:global_step/sec: 13.7435
# I0810 01:30:22.049543 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7435
# INFO:tensorflow:loss = 4.145456, step = 16500 (7.276 sec)
# I0810 01:30:22.050640 140158977697664 basic_session_run_hooks.py:260] loss = 4.145456, step = 16500 (7.276 sec)
# INFO:tensorflow:global_step/sec: 13.7434
# I0810 01:30:29.325752 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7434
# INFO:tensorflow:loss = 0.8689765, step = 16600 (7.276 sec)
# I0810 01:30:29.326799 140158977697664 basic_session_run_hooks.py:260] loss = 0.8689765, step = 16600 (7.276 sec)
# INFO:tensorflow:global_step/sec: 13.5753
# I0810 01:30:36.692059 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5753
# INFO:tensorflow:loss = 4.682961, step = 16700 (7.366 sec)
# I0810 01:30:36.692985 140158977697664 basic_session_run_hooks.py:260] loss = 4.682961, step = 16700 (7.366 sec)
# INFO:tensorflow:global_step/sec: 13.5754
# I0810 01:30:44.058332 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5754
# INFO:tensorflow:loss = 2.4719481, step = 16800 (7.366 sec)
# I0810 01:30:44.059364 140158977697664 basic_session_run_hooks.py:260] loss = 2.4719481, step = 16800 (7.366 sec)
# INFO:tensorflow:global_step/sec: 13.8872
# I0810 01:30:51.259236 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8872
# INFO:tensorflow:loss = 3.4937751, step = 16900 (7.201 sec)
# I0810 01:30:51.260522 140158977697664 basic_session_run_hooks.py:260] loss = 3.4937751, step = 16900 (7.201 sec)
# INFO:tensorflow:global_step/sec: 13.095
# I0810 01:30:58.895777 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.095
# INFO:tensorflow:loss = 2.217885, step = 17000 (7.636 sec)
# I0810 01:30:58.897002 140158977697664 basic_session_run_hooks.py:260] loss = 2.217885, step = 17000 (7.636 sec)
# INFO:tensorflow:global_step/sec: 13.0545
# I0810 01:31:06.555944 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.0545
# INFO:tensorflow:loss = 2.6587114, step = 17100 (7.660 sec)
# I0810 01:31:06.556864 140158977697664 basic_session_run_hooks.py:260] loss = 2.6587114, step = 17100 (7.660 sec)
# INFO:tensorflow:global_step/sec: 13.7745
# I0810 01:31:13.815716 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7745
# INFO:tensorflow:loss = 2.9036489, step = 17200 (7.260 sec)
# I0810 01:31:13.816846 140158977697664 basic_session_run_hooks.py:260] loss = 2.9036489, step = 17200 (7.260 sec)
# INFO:tensorflow:global_step/sec: 13.4914
# I0810 01:31:21.227803 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4914
# INFO:tensorflow:loss = 2.468113, step = 17300 (7.412 sec)
# I0810 01:31:21.228870 140158977697664 basic_session_run_hooks.py:260] loss = 2.468113, step = 17300 (7.412 sec)
# INFO:tensorflow:global_step/sec: 13.4468
# I0810 01:31:28.664508 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4468
# INFO:tensorflow:loss = 2.4743152, step = 17400 (7.437 sec)
# I0810 01:31:28.665437 140158977697664 basic_session_run_hooks.py:260] loss = 2.4743152, step = 17400 (7.437 sec)
# INFO:tensorflow:global_step/sec: 14.1325
# I0810 01:31:35.740409 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.1325
# INFO:tensorflow:loss = 2.6496613, step = 17500 (7.076 sec)
# I0810 01:31:35.741524 140158977697664 basic_session_run_hooks.py:260] loss = 2.6496613, step = 17500 (7.076 sec)
# INFO:tensorflow:global_step/sec: 13.4279
# I0810 01:31:43.187604 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4279
# INFO:tensorflow:loss = 2.9086404, step = 17600 (7.447 sec)
# I0810 01:31:43.188737 140158977697664 basic_session_run_hooks.py:260] loss = 2.9086404, step = 17600 (7.447 sec)
# INFO:tensorflow:global_step/sec: 13.6633
# I0810 01:31:50.506476 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6633
# INFO:tensorflow:loss = 4.3395176, step = 17700 (7.319 sec)
# I0810 01:31:50.507570 140158977697664 basic_session_run_hooks.py:260] loss = 4.3395176, step = 17700 (7.319 sec)
# INFO:tensorflow:global_step/sec: 13.2221
# I0810 01:31:58.069627 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.2221
# INFO:tensorflow:loss = 2.4020596, step = 17800 (7.563 sec)
# I0810 01:31:58.070780 140158977697664 basic_session_run_hooks.py:260] loss = 2.4020596, step = 17800 (7.563 sec)
# INFO:tensorflow:global_step/sec: 13.7779
# I0810 01:32:05.327550 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7779
# INFO:tensorflow:loss = 3.3779707, step = 17900 (7.258 sec)
# I0810 01:32:05.328676 140158977697664 basic_session_run_hooks.py:260] loss = 3.3779707, step = 17900 (7.258 sec)
# INFO:tensorflow:global_step/sec: 13.453
# I0810 01:32:12.760829 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.453
# INFO:tensorflow:loss = 1.4029937, step = 18000 (7.434 sec)
# I0810 01:32:12.762407 140158977697664 basic_session_run_hooks.py:260] loss = 1.4029937, step = 18000 (7.434 sec)
# INFO:tensorflow:global_step/sec: 13.8799
# I0810 01:32:19.965483 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8799
# INFO:tensorflow:loss = 2.8852124, step = 18100 (7.204 sec)
# I0810 01:32:19.966356 140158977697664 basic_session_run_hooks.py:260] loss = 2.8852124, step = 18100 (7.204 sec)
# INFO:tensorflow:global_step/sec: 13.4857
# I0810 01:32:27.380760 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4857
# INFO:tensorflow:loss = 1.4429386, step = 18200 (7.415 sec)
# I0810 01:32:27.381667 140158977697664 basic_session_run_hooks.py:260] loss = 1.4429386, step = 18200 (7.415 sec)
# INFO:tensorflow:global_step/sec: 13.4831
# I0810 01:32:34.797451 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4831
# INFO:tensorflow:loss = 1.3200486, step = 18300 (7.417 sec)
# I0810 01:32:34.798521 140158977697664 basic_session_run_hooks.py:260] loss = 1.3200486, step = 18300 (7.417 sec)
# INFO:tensorflow:global_step/sec: 13.5289
# I0810 01:32:42.189035 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5289
# INFO:tensorflow:loss = 2.0191507, step = 18400 (7.391 sec)
# I0810 01:32:42.189992 140158977697664 basic_session_run_hooks.py:260] loss = 2.0191507, step = 18400 (7.391 sec)
# INFO:tensorflow:global_step/sec: 13.8458
# I0810 01:32:49.411475 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8458
# INFO:tensorflow:loss = 2.6665475, step = 18500 (7.222 sec)
# I0810 01:32:49.412375 140158977697664 basic_session_run_hooks.py:260] loss = 2.6665475, step = 18500 (7.222 sec)
# INFO:tensorflow:global_step/sec: 12.9976
# I0810 01:32:57.105171 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 12.9976
# INFO:tensorflow:loss = 1.7621384, step = 18600 (7.694 sec)
# I0810 01:32:57.106229 140158977697664 basic_session_run_hooks.py:260] loss = 1.7621384, step = 18600 (7.694 sec)
# INFO:tensorflow:global_step/sec: 13.6346
# I0810 01:33:04.439424 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6346
# INFO:tensorflow:loss = 2.097577, step = 18700 (7.334 sec)
# I0810 01:33:04.440607 140158977697664 basic_session_run_hooks.py:260] loss = 2.097577, step = 18700 (7.334 sec)
# INFO:tensorflow:global_step/sec: 13.8725
# I0810 01:33:11.647933 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8725
# INFO:tensorflow:loss = 2.1128361, step = 18800 (7.208 sec)
# I0810 01:33:11.648856 140158977697664 basic_session_run_hooks.py:260] loss = 2.1128361, step = 18800 (7.208 sec)
# INFO:tensorflow:global_step/sec: 13.5824
# I0810 01:33:19.010398 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5824
# INFO:tensorflow:loss = 1.5836095, step = 18900 (7.363 sec)
# I0810 01:33:19.011665 140158977697664 basic_session_run_hooks.py:260] loss = 1.5836095, step = 18900 (7.363 sec)
# INFO:tensorflow:global_step/sec: 13.1329
# I0810 01:33:26.624845 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1329
# INFO:tensorflow:loss = 2.2772624, step = 19000 (7.614 sec)
# I0810 01:33:26.625896 140158977697664 basic_session_run_hooks.py:260] loss = 2.2772624, step = 19000 (7.614 sec)
# INFO:tensorflow:global_step/sec: 13.3235
# I0810 01:33:34.130409 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3235
# INFO:tensorflow:loss = 2.873572, step = 19100 (7.505 sec)
# I0810 01:33:34.131356 140158977697664 basic_session_run_hooks.py:260] loss = 2.873572, step = 19100 (7.505 sec)
# INFO:tensorflow:global_step/sec: 13.3701
# I0810 01:33:41.609804 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3701
# INFO:tensorflow:loss = 3.425072, step = 19200 (7.480 sec)
# I0810 01:33:41.610872 140158977697664 basic_session_run_hooks.py:260] loss = 3.425072, step = 19200 (7.480 sec)
# INFO:tensorflow:global_step/sec: 13.4927
# I0810 01:33:49.021228 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4927
# INFO:tensorflow:loss = 4.5112967, step = 19300 (7.411 sec)
# I0810 01:33:49.022326 140158977697664 basic_session_run_hooks.py:260] loss = 4.5112967, step = 19300 (7.411 sec)
# INFO:tensorflow:global_step/sec: 13.6432
# I0810 01:33:56.350901 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6432
# INFO:tensorflow:loss = 2.9838207, step = 19400 (7.330 sec)
# I0810 01:33:56.352062 140158977697664 basic_session_run_hooks.py:260] loss = 2.9838207, step = 19400 (7.330 sec)
# INFO:tensorflow:global_step/sec: 13.7536
# I0810 01:34:03.621733 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7536
# INFO:tensorflow:loss = 1.3578519, step = 19500 (7.271 sec)
# I0810 01:34:03.622663 140158977697664 basic_session_run_hooks.py:260] loss = 1.3578519, step = 19500 (7.271 sec)
# INFO:tensorflow:global_step/sec: 13.5571
# I0810 01:34:10.997905 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5571
# INFO:tensorflow:loss = 1.8118848, step = 19600 (7.376 sec)
# I0810 01:34:10.998907 140158977697664 basic_session_run_hooks.py:260] loss = 1.8118848, step = 19600 (7.376 sec)
# INFO:tensorflow:global_step/sec: 13.6553
# I0810 01:34:18.321046 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6553
# INFO:tensorflow:loss = 1.7811357, step = 19700 (7.324 sec)
# I0810 01:34:18.322612 140158977697664 basic_session_run_hooks.py:260] loss = 1.7811357, step = 19700 (7.324 sec)
# INFO:tensorflow:global_step/sec: 13.5521
# I0810 01:34:25.700019 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5521
# INFO:tensorflow:loss = 1.2783164, step = 19800 (7.379 sec)
# I0810 01:34:25.701343 140158977697664 basic_session_run_hooks.py:260] loss = 1.2783164, step = 19800 (7.379 sec)
# INFO:tensorflow:global_step/sec: 13.5405
# I0810 01:34:33.085247 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5405
# INFO:tensorflow:loss = 1.4977751, step = 19900 (7.385 sec)
# I0810 01:34:33.086364 140158977697664 basic_session_run_hooks.py:260] loss = 1.4977751, step = 19900 (7.385 sec)
# INFO:tensorflow:global_step/sec: 13.6868
# I0810 01:34:40.391565 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6868
# INFO:tensorflow:loss = 3.0883572, step = 20000 (7.306 sec)
# I0810 01:34:40.392717 140158977697664 basic_session_run_hooks.py:260] loss = 3.0883572, step = 20000 (7.306 sec)
# INFO:tensorflow:global_step/sec: 13.7827
# I0810 01:34:47.647046 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7827
# INFO:tensorflow:loss = 3.1810882, step = 20100 (7.255 sec)
# I0810 01:34:47.647966 140158977697664 basic_session_run_hooks.py:260] loss = 3.1810882, step = 20100 (7.255 sec)
# INFO:tensorflow:global_step/sec: 13.8405
# I0810 01:34:54.872211 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8405
# INFO:tensorflow:loss = 1.48588, step = 20200 (7.225 sec)
# I0810 01:34:54.873181 140158977697664 basic_session_run_hooks.py:260] loss = 1.48588, step = 20200 (7.225 sec)
# INFO:tensorflow:global_step/sec: 13.5781
# I0810 01:35:02.236989 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5781
# INFO:tensorflow:loss = 2.1383672, step = 20300 (7.365 sec)
# I0810 01:35:02.237912 140158977697664 basic_session_run_hooks.py:260] loss = 2.1383672, step = 20300 (7.365 sec)
# INFO:tensorflow:global_step/sec: 13.6366
# I0810 01:35:09.570230 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6366
# INFO:tensorflow:loss = 4.0644584, step = 20400 (7.333 sec)
# I0810 01:35:09.571410 140158977697664 basic_session_run_hooks.py:260] loss = 4.0644584, step = 20400 (7.333 sec)
# INFO:tensorflow:global_step/sec: 13.7715
# I0810 01:35:16.831620 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7715
# INFO:tensorflow:loss = 2.3480456, step = 20500 (7.261 sec)
# I0810 01:35:16.832742 140158977697664 basic_session_run_hooks.py:260] loss = 2.3480456, step = 20500 (7.261 sec)
# INFO:tensorflow:global_step/sec: 13.7585
# I0810 01:35:24.099828 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7585
# INFO:tensorflow:loss = 2.1777782, step = 20600 (7.268 sec)
# I0810 01:35:24.100920 140158977697664 basic_session_run_hooks.py:260] loss = 2.1777782, step = 20600 (7.268 sec)
# INFO:tensorflow:global_step/sec: 13.6555
# I0810 01:35:31.422919 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6555
# INFO:tensorflow:loss = 2.4749482, step = 20700 (7.323 sec)
# I0810 01:35:31.424104 140158977697664 basic_session_run_hooks.py:260] loss = 2.4749482, step = 20700 (7.323 sec)
# INFO:tensorflow:global_step/sec: 13.5685
# I0810 01:35:38.792917 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5685
# INFO:tensorflow:loss = 1.9877421, step = 20800 (7.370 sec)
# I0810 01:35:38.794010 140158977697664 basic_session_run_hooks.py:260] loss = 1.9877421, step = 20800 (7.370 sec)
# INFO:tensorflow:global_step/sec: 13.7544
# I0810 01:35:46.063317 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7544
# INFO:tensorflow:loss = 2.0534096, step = 20900 (7.271 sec)
# I0810 01:35:46.064643 140158977697664 basic_session_run_hooks.py:260] loss = 2.0534096, step = 20900 (7.271 sec)
# INFO:tensorflow:global_step/sec: 13.8121
# I0810 01:35:53.303355 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8121
# INFO:tensorflow:loss = 2.1779358, step = 21000 (7.240 sec)
# I0810 01:35:53.304315 140158977697664 basic_session_run_hooks.py:260] loss = 2.1779358, step = 21000 (7.240 sec)
# INFO:tensorflow:global_step/sec: 13.7195
# I0810 01:36:00.592256 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7195
# INFO:tensorflow:loss = 4.363944, step = 21100 (7.289 sec)
# I0810 01:36:00.593229 140158977697664 basic_session_run_hooks.py:260] loss = 4.363944, step = 21100 (7.289 sec)
# INFO:tensorflow:global_step/sec: 13.7256
# I0810 01:36:07.877930 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7256
# INFO:tensorflow:loss = 1.6886761, step = 21200 (7.286 sec)
# I0810 01:36:07.879058 140158977697664 basic_session_run_hooks.py:260] loss = 1.6886761, step = 21200 (7.286 sec)
# INFO:tensorflow:global_step/sec: 13.5702
# I0810 01:36:15.247037 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5702
# INFO:tensorflow:loss = 1.7326988, step = 21300 (7.369 sec)
# I0810 01:36:15.247915 140158977697664 basic_session_run_hooks.py:260] loss = 1.7326988, step = 21300 (7.369 sec)
# INFO:tensorflow:global_step/sec: 13.5723
# I0810 01:36:22.614972 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5723
# INFO:tensorflow:loss = 3.5302043, step = 21400 (7.369 sec)
# I0810 01:36:22.616720 140158977697664 basic_session_run_hooks.py:260] loss = 3.5302043, step = 21400 (7.369 sec)
# INFO:tensorflow:global_step/sec: 13.8249
# I0810 01:36:29.848268 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8249
# INFO:tensorflow:loss = 4.2342343, step = 21500 (7.233 sec)
# I0810 01:36:29.849323 140158977697664 basic_session_run_hooks.py:260] loss = 4.2342343, step = 21500 (7.233 sec)
# INFO:tensorflow:global_step/sec: 14.1339
# I0810 01:36:36.923463 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.1339
# INFO:tensorflow:loss = 3.550613, step = 21600 (7.075 sec)
# I0810 01:36:36.924571 140158977697664 basic_session_run_hooks.py:260] loss = 3.550613, step = 21600 (7.075 sec)
# INFO:tensorflow:global_step/sec: 13.3856
# I0810 01:36:44.394252 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3856
# INFO:tensorflow:loss = 4.2571464, step = 21700 (7.471 sec)
# I0810 01:36:44.395742 140158977697664 basic_session_run_hooks.py:260] loss = 4.2571464, step = 21700 (7.471 sec)
# INFO:tensorflow:global_step/sec: 13.5356
# I0810 01:36:51.782138 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5356
# INFO:tensorflow:loss = 1.3963182, step = 21800 (7.387 sec)
# I0810 01:36:51.783088 140158977697664 basic_session_run_hooks.py:260] loss = 1.3963182, step = 21800 (7.387 sec)
# INFO:tensorflow:global_step/sec: 13.8468
# I0810 01:36:59.004108 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8468
# INFO:tensorflow:loss = 2.7062943, step = 21900 (7.222 sec)
# I0810 01:36:59.005059 140158977697664 basic_session_run_hooks.py:260] loss = 2.7062943, step = 21900 (7.222 sec)
# INFO:tensorflow:global_step/sec: 13.9248
# I0810 01:37:06.185461 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9248
# INFO:tensorflow:loss = 2.0146024, step = 22000 (7.182 sec)
# I0810 01:37:06.186658 140158977697664 basic_session_run_hooks.py:260] loss = 2.0146024, step = 22000 (7.182 sec)
# INFO:tensorflow:global_step/sec: 13.8017
# I0810 01:37:13.430962 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8017
# INFO:tensorflow:loss = 3.6591787, step = 22100 (7.245 sec)
# I0810 01:37:13.431973 140158977697664 basic_session_run_hooks.py:260] loss = 3.6591787, step = 22100 (7.245 sec)
# INFO:tensorflow:global_step/sec: 13.7978
# I0810 01:37:20.678504 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7978
# INFO:tensorflow:loss = 1.5557747, step = 22200 (7.248 sec)
# I0810 01:37:20.679612 140158977697664 basic_session_run_hooks.py:260] loss = 1.5557747, step = 22200 (7.248 sec)
# INFO:tensorflow:global_step/sec: 13.7128
# I0810 01:37:27.970962 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7128
# ...
# INFO:tensorflow:loss = 2.0119638, step = 106400 (7.267 sec)
# I0810 03:21:36.738896 140158977697664 basic_session_run_hooks.py:260] loss = 2.0119638, step = 106400 (7.267 sec)
# INFO:tensorflow:global_step/sec: 13.5863
# I0810 03:21:44.098228 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5863
# INFO:tensorflow:loss = 2.7171257, step = 106500 (7.360 sec)
# I0810 03:21:44.099196 140158977697664 basic_session_run_hooks.py:260] loss = 2.7171257, step = 106500 (7.360 sec)
# INFO:tensorflow:global_step/sec: 13.4797
# I0810 03:21:51.516809 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4797
# INFO:tensorflow:loss = 3.4671202, step = 106600 (7.419 sec)
# I0810 03:21:51.517889 140158977697664 basic_session_run_hooks.py:260] loss = 3.4671202, step = 106600 (7.419 sec)
# INFO:tensorflow:global_step/sec: 13.1723
# I0810 03:21:59.108478 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1723
# INFO:tensorflow:loss = 1.2189271, step = 106700 (7.592 sec)
# I0810 03:21:59.109573 140158977697664 basic_session_run_hooks.py:260] loss = 1.2189271, step = 106700 (7.592 sec)
# INFO:tensorflow:global_step/sec: 13.7918
# I0810 03:22:06.359161 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7918
# INFO:tensorflow:loss = 1.606092, step = 106800 (7.251 sec)
# I0810 03:22:06.360110 140158977697664 basic_session_run_hooks.py:260] loss = 1.606092, step = 106800 (7.251 sec)
# INFO:tensorflow:global_step/sec: 13.4638
# I0810 03:22:13.786476 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4638
# INFO:tensorflow:loss = 0.9740802, step = 106900 (7.428 sec)
# I0810 03:22:13.788183 140158977697664 basic_session_run_hooks.py:260] loss = 0.9740802, step = 106900 (7.428 sec)
# INFO:tensorflow:global_step/sec: 13.3442
# I0810 03:22:21.280350 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3442
# INFO:tensorflow:loss = 1.2562089, step = 107000 (7.493 sec)
# I0810 03:22:21.281378 140158977697664 basic_session_run_hooks.py:260] loss = 1.2562089, step = 107000 (7.493 sec)
# INFO:tensorflow:global_step/sec: 13.5122
# I0810 03:22:28.681098 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5122
# INFO:tensorflow:loss = 1.7680578, step = 107100 (7.401 sec)
# I0810 03:22:28.682249 140158977697664 basic_session_run_hooks.py:260] loss = 1.7680578, step = 107100 (7.401 sec)
# INFO:tensorflow:global_step/sec: 14.0834
# I0810 03:22:35.781755 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0834
# INFO:tensorflow:loss = 1.3211217, step = 107200 (7.101 sec)
# I0810 03:22:35.782859 140158977697664 basic_session_run_hooks.py:260] loss = 1.3211217, step = 107200 (7.101 sec)
# INFO:tensorflow:global_step/sec: 14.1493
# I0810 03:22:42.849163 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.1493
# INFO:tensorflow:loss = 0.958612, step = 107300 (7.067 sec)
# I0810 03:22:42.850262 140158977697664 basic_session_run_hooks.py:260] loss = 0.958612, step = 107300 (7.067 sec)
# INFO:tensorflow:global_step/sec: 13.7057
# I0810 03:22:50.145418 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7057
# INFO:tensorflow:loss = 1.1452086, step = 107400 (7.296 sec)
# I0810 03:22:50.146567 140158977697664 basic_session_run_hooks.py:260] loss = 1.1452086, step = 107400 (7.296 sec)
# INFO:tensorflow:global_step/sec: 14.0942
# I0810 03:22:57.240555 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0942
# INFO:tensorflow:loss = 2.091745, step = 107500 (7.095 sec)
# I0810 03:22:57.241748 140158977697664 basic_session_run_hooks.py:260] loss = 2.091745, step = 107500 (7.095 sec)
# INFO:tensorflow:global_step/sec: 13.1936
# I0810 03:23:04.819995 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1936
# INFO:tensorflow:loss = 1.2698692, step = 107600 (7.579 sec)
# I0810 03:23:04.820911 140158977697664 basic_session_run_hooks.py:260] loss = 1.2698692, step = 107600 (7.579 sec)
# INFO:tensorflow:global_step/sec: 13.4583
# I0810 03:23:12.250353 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4583
# INFO:tensorflow:loss = 1.718988, step = 107700 (7.431 sec)
# I0810 03:23:12.251428 140158977697664 basic_session_run_hooks.py:260] loss = 1.718988, step = 107700 (7.431 sec)
# INFO:tensorflow:global_step/sec: 13.8013
# I0810 03:23:19.496059 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8013
# INFO:tensorflow:loss = 2.340357, step = 107800 (7.246 sec)
# I0810 03:23:19.497040 140158977697664 basic_session_run_hooks.py:260] loss = 2.340357, step = 107800 (7.246 sec)
# INFO:tensorflow:global_step/sec: 13.8357
# I0810 03:23:26.723755 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8357
# INFO:tensorflow:loss = 1.1165202, step = 107900 (7.228 sec)
# I0810 03:23:26.724949 140158977697664 basic_session_run_hooks.py:260] loss = 1.1165202, step = 107900 (7.228 sec)
# INFO:tensorflow:global_step/sec: 13.7431
# I0810 03:23:34.000130 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7431
# INFO:tensorflow:loss = 1.3544831, step = 108000 (7.276 sec)
# I0810 03:23:34.001332 140158977697664 basic_session_run_hooks.py:260] loss = 1.3544831, step = 108000 (7.276 sec)
# INFO:tensorflow:global_step/sec: 13.6223
# I0810 03:23:41.341015 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6223
# INFO:tensorflow:loss = 2.2598069, step = 108100 (7.341 sec)
# I0810 03:23:41.341960 140158977697664 basic_session_run_hooks.py:260] loss = 2.2598069, step = 108100 (7.341 sec)
# INFO:tensorflow:global_step/sec: 13.5394
# I0810 03:23:48.726840 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5394
# INFO:tensorflow:loss = 0.99974114, step = 108200 (7.386 sec)
# I0810 03:23:48.727899 140158977697664 basic_session_run_hooks.py:260] loss = 0.99974114, step = 108200 (7.386 sec)
# INFO:tensorflow:global_step/sec: 13.7299
# I0810 03:23:56.010202 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7299
# INFO:tensorflow:loss = 2.5749762, step = 108300 (7.283 sec)
# I0810 03:23:56.011190 140158977697664 basic_session_run_hooks.py:260] loss = 2.5749762, step = 108300 (7.283 sec)
# INFO:tensorflow:global_step/sec: 13.7411
# I0810 03:24:03.287669 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7411
# INFO:tensorflow:loss = 2.4753008, step = 108400 (7.277 sec)
# I0810 03:24:03.288651 140158977697664 basic_session_run_hooks.py:260] loss = 2.4753008, step = 108400 (7.277 sec)
# INFO:tensorflow:global_step/sec: 13.6246
# I0810 03:24:10.627316 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6246
# INFO:tensorflow:loss = 1.4595, step = 108500 (7.340 sec)
# I0810 03:24:10.628393 140158977697664 basic_session_run_hooks.py:260] loss = 1.4595, step = 108500 (7.340 sec)
# INFO:tensorflow:global_step/sec: 13.7095
# I0810 03:24:17.921545 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7095
# INFO:tensorflow:loss = 1.9173002, step = 108600 (7.295 sec)
# I0810 03:24:17.923241 140158977697664 basic_session_run_hooks.py:260] loss = 1.9173002, step = 108600 (7.295 sec)
# INFO:tensorflow:global_step/sec: 13.1803
# I0810 03:24:25.508585 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1803
# INFO:tensorflow:loss = 4.0402584, step = 108700 (7.586 sec)
# I0810 03:24:25.509550 140158977697664 basic_session_run_hooks.py:260] loss = 4.0402584, step = 108700 (7.586 sec)
# INFO:tensorflow:global_step/sec: 13.1146
# I0810 03:24:33.133719 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.1146
# INFO:tensorflow:loss = 2.9580173, step = 108800 (7.625 sec)
# I0810 03:24:33.134656 140158977697664 basic_session_run_hooks.py:260] loss = 2.9580173, step = 108800 (7.625 sec)
# INFO:tensorflow:global_step/sec: 14.0088
# I0810 03:24:40.272064 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0088
# INFO:tensorflow:loss = 2.114584, step = 108900 (7.138 sec)
# I0810 03:24:40.273067 140158977697664 basic_session_run_hooks.py:260] loss = 2.114584, step = 108900 (7.138 sec)
# INFO:tensorflow:global_step/sec: 13.5824
# I0810 03:24:47.634519 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5824
# INFO:tensorflow:loss = 0.9870962, step = 109000 (7.363 sec)
# I0810 03:24:47.635801 140158977697664 basic_session_run_hooks.py:260] loss = 0.9870962, step = 109000 (7.363 sec)
# INFO:tensorflow:global_step/sec: 13.6647
# I0810 03:24:54.952638 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6647
# INFO:tensorflow:loss = 1.7861767, step = 109100 (7.318 sec)
# I0810 03:24:54.953685 140158977697664 basic_session_run_hooks.py:260] loss = 1.7861767, step = 109100 (7.318 sec)
# INFO:tensorflow:global_step/sec: 13.8252
# I0810 03:25:02.185792 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.8252
# INFO:tensorflow:loss = 2.5520732, step = 109200 (7.233 sec)
# I0810 03:25:02.186914 140158977697664 basic_session_run_hooks.py:260] loss = 2.5520732, step = 109200 (7.233 sec)
# INFO:tensorflow:global_step/sec: 13.7634
# I0810 03:25:09.451421 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7634
# INFO:tensorflow:loss = 1.3143542, step = 109300 (7.265 sec)
# I0810 03:25:09.452417 140158977697664 basic_session_run_hooks.py:260] loss = 1.3143542, step = 109300 (7.265 sec)
# INFO:tensorflow:global_step/sec: 13.5466
# I0810 03:25:16.833353 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5466
# INFO:tensorflow:loss = 0.7761452, step = 109400 (7.382 sec)
# I0810 03:25:16.834443 140158977697664 basic_session_run_hooks.py:260] loss = 0.7761452, step = 109400 (7.382 sec)
# INFO:tensorflow:global_step/sec: 13.4801
# I0810 03:25:24.251705 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4801
# INFO:tensorflow:loss = 2.7968178, step = 109500 (7.418 sec)
# I0810 03:25:24.252800 140158977697664 basic_session_run_hooks.py:260] loss = 2.7968178, step = 109500 (7.418 sec)
# INFO:tensorflow:global_step/sec: 13.5437
# I0810 03:25:31.635172 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5437
# INFO:tensorflow:loss = 1.7513509, step = 109600 (7.383 sec)
# I0810 03:25:31.636266 140158977697664 basic_session_run_hooks.py:260] loss = 1.7513509, step = 109600 (7.383 sec)
# INFO:tensorflow:global_step/sec: 13.5387
# I0810 03:25:39.021409 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5387
# INFO:tensorflow:loss = 0.9288111, step = 109700 (7.386 sec)
# I0810 03:25:39.022498 140158977697664 basic_session_run_hooks.py:260] loss = 0.9288111, step = 109700 (7.386 sec)
# INFO:tensorflow:global_step/sec: 13.7484
# I0810 03:25:46.295015 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7484
# INFO:tensorflow:loss = 3.0846238, step = 109800 (7.274 sec)
# I0810 03:25:46.296079 140158977697664 basic_session_run_hooks.py:260] loss = 3.0846238, step = 109800 (7.274 sec)
# INFO:tensorflow:global_step/sec: 13.6777
# I0810 03:25:53.606170 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6777
# INFO:tensorflow:loss = 2.5706868, step = 109900 (7.311 sec)
# I0810 03:25:53.607128 140158977697664 basic_session_run_hooks.py:260] loss = 2.5706868, step = 109900 (7.311 sec)
# INFO:tensorflow:global_step/sec: 13.6214
# I0810 03:26:00.947565 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.6214
# INFO:tensorflow:loss = 2.9939637, step = 110000 (7.341 sec)
# I0810 03:26:00.948554 140158977697664 basic_session_run_hooks.py:260] loss = 2.9939637, step = 110000 (7.341 sec)
# INFO:tensorflow:global_step/sec: 14.0902
# I0810 03:26:08.044732 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0902
# INFO:tensorflow:loss = 2.0455806, step = 110100 (7.097 sec)
# I0810 03:26:08.045889 140158977697664 basic_session_run_hooks.py:260] loss = 2.0455806, step = 110100 (7.097 sec)
# INFO:tensorflow:global_step/sec: 14.0171
# I0810 03:26:15.178835 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.0171
# INFO:tensorflow:loss = 4.488049, step = 110200 (7.134 sec)
# I0810 03:26:15.180067 140158977697664 basic_session_run_hooks.py:260] loss = 4.488049, step = 110200 (7.134 sec)
# INFO:tensorflow:global_step/sec: 13.7919
# I0810 03:26:22.429446 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7919
# INFO:tensorflow:loss = 2.5750308, step = 110300 (7.256 sec)
# I0810 03:26:22.435729 140158977697664 basic_session_run_hooks.py:260] loss = 2.5750308, step = 110300 (7.256 sec)
# INFO:tensorflow:global_step/sec: 13.4785
# I0810 03:26:29.848678 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4785
# INFO:tensorflow:loss = 1.6386418, step = 110400 (7.414 sec)
# I0810 03:26:29.849774 140158977697664 basic_session_run_hooks.py:260] loss = 1.6386418, step = 110400 (7.414 sec)
# INFO:tensorflow:global_step/sec: 13.9612
# I0810 03:26:37.011351 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9612
# INFO:tensorflow:loss = 2.1365736, step = 110500 (7.163 sec)
# I0810 03:26:37.012571 140158977697664 basic_session_run_hooks.py:260] loss = 2.1365736, step = 110500 (7.163 sec)
# INFO:tensorflow:global_step/sec: 13.7533
# I0810 03:26:44.282309 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7533
# INFO:tensorflow:loss = 1.4336361, step = 110600 (7.271 sec)
# I0810 03:26:44.283472 140158977697664 basic_session_run_hooks.py:260] loss = 1.4336361, step = 110600 (7.271 sec)
# INFO:tensorflow:global_step/sec: 13.4105
# I0810 03:26:51.739145 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.4105
# INFO:tensorflow:loss = 2.2323632, step = 110700 (7.457 sec)
# I0810 03:26:51.740251 140158977697664 basic_session_run_hooks.py:260] loss = 2.2323632, step = 110700 (7.457 sec)
# INFO:tensorflow:global_step/sec: 13.3083
# I0810 03:26:59.253242 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3083
# INFO:tensorflow:loss = 2.6725836, step = 110800 (7.514 sec)
# I0810 03:26:59.254208 140158977697664 basic_session_run_hooks.py:260] loss = 2.6725836, step = 110800 (7.514 sec)
# INFO:tensorflow:global_step/sec: 14.1163
# I0810 03:27:06.337262 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 14.1163
# INFO:tensorflow:loss = 3.2720551, step = 110900 (7.084 sec)
# I0810 03:27:06.338126 140158977697664 basic_session_run_hooks.py:260] loss = 3.2720551, step = 110900 (7.084 sec)
# INFO:tensorflow:global_step/sec: 13.788
# I0810 03:27:13.589949 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.788
# INFO:tensorflow:loss = 2.0076056, step = 111000 (7.253 sec)
# I0810 03:27:13.591041 140158977697664 basic_session_run_hooks.py:260] loss = 2.0076056, step = 111000 (7.253 sec)
# INFO:tensorflow:global_step/sec: 13.7074
# I0810 03:27:20.885227 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.7074
# INFO:tensorflow:loss = 2.2231364, step = 111100 (7.295 sec)
# I0810 03:27:20.886192 140158977697664 basic_session_run_hooks.py:260] loss = 2.2231364, step = 111100 (7.295 sec)
# INFO:tensorflow:global_step/sec: 12.9934
# I0810 03:27:28.581468 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 12.9934
# INFO:tensorflow:loss = 1.4122028, step = 111200 (7.696 sec)
# I0810 03:27:28.582624 140158977697664 basic_session_run_hooks.py:260] loss = 1.4122028, step = 111200 (7.696 sec)
# INFO:tensorflow:global_step/sec: 13.3011
# I0810 03:27:36.099620 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.3011
# INFO:tensorflow:loss = 3.06084, step = 111300 (7.518 sec)
# I0810 03:27:36.100672 140158977697664 basic_session_run_hooks.py:260] loss = 3.06084, step = 111300 (7.518 sec)
# INFO:tensorflow:global_step/sec: 13.5094
# I0810 03:27:43.501851 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.5094
# INFO:tensorflow:loss = 2.2874146, step = 111400 (7.402 sec)
# I0810 03:27:43.502887 140158977697664 basic_session_run_hooks.py:260] loss = 2.2874146, step = 111400 (7.402 sec)
# INFO:tensorflow:global_step/sec: 13.9461
# I0810 03:27:50.672343 140158977697664 basic_session_run_hooks.py:692] global_step/sec: 13.9461
# INFO:tensorflow:loss = 2.3354976, step = 111500 (7.171 sec)
# I0810 03:27:50.673524 140158977697664 basic_session_run_hooks.py:260] loss = 2.3354976, step = 111500 (7.171 sec)

# %%
output_directory = './fine_tuned_model'

lst = os.listdir('training')
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join('training', last_model)

# %%
# !python /gdrive/'My Drive'/object_detection/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path=/gdrive/My\ Drive/object_detection/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0810 05:54:00.878448 140172771014528 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:02.815385 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:02.944247 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:02.979043 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:03.012643 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:03.045988 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0810 05:54:03.079874 140172771014528 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /gdrive/My Drive/object_detection/models/research/object_detection/core/post_processing.py:583: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0810 05:54:03.314964 140172771014528 deprecation.py:323] From /gdrive/My Drive/object_detection/models/research/object_detection/core/post_processing.py:583: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W0810 05:54:03.710162 140172771014528 deprecation.py:323] From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W0810 05:54:03.713187 140172771014528 deprecation.py:323] From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W0810 05:54:03.713770 140172771014528 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 137 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/4.61m params)
#   BoxPredictor_0 (--/13.85k params)
#     BoxPredictor_0/BoxEncodingPredictor (--/6.92k params)
#       BoxPredictor_0/BoxEncodingPredictor/biases (12, 12/12 params)
#       BoxPredictor_0/BoxEncodingPredictor/weights (1x1x576x12, 6.91k/6.91k params)
#     BoxPredictor_0/ClassPredictor (--/6.92k params)
#       BoxPredictor_0/ClassPredictor/biases (12, 12/12 params)
#       BoxPredictor_0/ClassPredictor/weights (1x1x576x12, 6.91k/6.91k params)
#   BoxPredictor_1 (--/61.49k params)
#     BoxPredictor_1/BoxEncodingPredictor (--/30.74k params)
#       BoxPredictor_1/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_1/BoxEncodingPredictor/weights (1x1x1280x24, 30.72k/30.72k params)
#     BoxPredictor_1/ClassPredictor (--/30.74k params)
#       BoxPredictor_1/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_1/ClassPredictor/weights (1x1x1280x24, 30.72k/30.72k params)
#   BoxPredictor_2 (--/24.62k params)
#     BoxPredictor_2/BoxEncodingPredictor (--/12.31k params)
#       BoxPredictor_2/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_2/BoxEncodingPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#     BoxPredictor_2/ClassPredictor (--/12.31k params)
#       BoxPredictor_2/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_2/ClassPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#   BoxPredictor_3 (--/12.34k params)
#     BoxPredictor_3/BoxEncodingPredictor (--/6.17k params)
#       BoxPredictor_3/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_3/BoxEncodingPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#     BoxPredictor_3/ClassPredictor (--/6.17k params)
#       BoxPredictor_3/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_3/ClassPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#   BoxPredictor_4 (--/12.34k params)
#     BoxPredictor_4/BoxEncodingPredictor (--/6.17k params)
#       BoxPredictor_4/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_4/BoxEncodingPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#     BoxPredictor_4/ClassPredictor (--/6.17k params)
#       BoxPredictor_4/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_4/ClassPredictor/weights (1x1x256x24, 6.14k/6.14k params)
#   BoxPredictor_5 (--/6.19k params)
#     BoxPredictor_5/BoxEncodingPredictor (--/3.10k params)
#       BoxPredictor_5/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_5/BoxEncodingPredictor/weights (1x1x128x24, 3.07k/3.07k params)
#     BoxPredictor_5/ClassPredictor (--/3.10k params)
#       BoxPredictor_5/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_5/ClassPredictor/weights (1x1x128x24, 3.07k/3.07k params)
#   FeatureExtractor (--/4.48m params)
#     FeatureExtractor/MobilenetV2 (--/4.48m params)
#       FeatureExtractor/MobilenetV2/Conv (--/864 params)
#         FeatureExtractor/MobilenetV2/Conv/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/Conv/weights (3x3x3x32, 864/864 params)
#       FeatureExtractor/MobilenetV2/Conv_1 (--/409.60k params)
#         FeatureExtractor/MobilenetV2/Conv_1/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/Conv_1/weights (1x1x320x1280, 409.60k/409.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv (--/800 params)
#         FeatureExtractor/MobilenetV2/expanded_conv/depthwise (--/288 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/depthwise/depthwise_weights (3x3x32x1, 288/288 params)
#         FeatureExtractor/MobilenetV2/expanded_conv/project (--/512 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv/project/weights (1x1x32x16, 512/512 params)
#       FeatureExtractor/MobilenetV2/expanded_conv_1 (--/4.70k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise (--/864 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/depthwise_weights (3x3x96x1, 864/864 params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/expand (--/1.54k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/expand/weights (1x1x16x96, 1.54k/1.54k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_1/project (--/2.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_1/project/weights (1x1x96x24, 2.30k/2.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_10 (--/64.90k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_10/project (--/36.86k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_10/project/weights (1x1x384x96, 36.86k/36.86k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_11 (--/115.78k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_11/project (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_11/project/weights (1x1x576x96, 55.30k/55.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_12 (--/115.78k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_12/project (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_12/project/weights (1x1x576x96, 55.30k/55.30k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_13 (--/152.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise (--/5.18k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/depthwise_weights (3x3x576x1, 5.18k/5.18k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/expand (--/55.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/expand/weights (1x1x96x576, 55.30k/55.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_13/project (--/92.16k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_13/project/weights (1x1x576x160, 92.16k/92.16k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_14 (--/315.84k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_14/project (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_14/project/weights (1x1x960x160, 153.60k/153.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_15 (--/315.84k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_15/project (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_15/project/weights (1x1x960x160, 153.60k/153.60k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_16 (--/469.44k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise (--/8.64k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/depthwise_weights (3x3x960x1, 8.64k/8.64k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/expand (--/153.60k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/expand/weights (1x1x160x960, 153.60k/153.60k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_16/project (--/307.20k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_16/project/weights (1x1x960x320, 307.20k/307.20k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_2 (--/8.21k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise (--/1.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/expand (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/expand/weights (1x1x24x144, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_2/project (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_2/project/weights (1x1x144x24, 3.46k/3.46k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_3 (--/9.36k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise (--/1.30k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/depthwise_weights (3x3x144x1, 1.30k/1.30k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/expand (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/expand/weights (1x1x24x144, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_3/project (--/4.61k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_3/project/weights (1x1x144x32, 4.61k/4.61k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_4 (--/14.02k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_4/project (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_4/project/weights (1x1x192x32, 6.14k/6.14k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_5 (--/14.02k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_5/project (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_5/project/weights (1x1x192x32, 6.14k/6.14k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_6 (--/20.16k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise (--/1.73k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/depthwise_weights (3x3x192x1, 1.73k/1.73k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/expand (--/6.14k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/expand/weights (1x1x32x192, 6.14k/6.14k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_6/project (--/12.29k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_6/project/weights (1x1x192x64, 12.29k/12.29k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_7 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_7/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_7/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_8 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_8/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_8/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/expanded_conv_9 (--/52.61k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise (--/3.46k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/depthwise_weights (3x3x384x1, 3.46k/3.46k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/expand (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/expand/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/expand/weights (1x1x64x384, 24.58k/24.58k params)
#         FeatureExtractor/MobilenetV2/expanded_conv_9/project (--/24.58k params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/project/BatchNorm (--/0 params)
#           FeatureExtractor/MobilenetV2/expanded_conv_9/project/weights (1x1x384x64, 24.58k/24.58k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256 (--/327.68k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/weights (1x1x1280x256, 327.68k/327.68k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128 (--/65.54k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/weights (1x1x512x128, 65.54k/65.54k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128 (--/32.77k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/weights (1x1x256x128, 32.77k/32.77k params)
#       FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64 (--/16.38k params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/weights (1x1x256x64, 16.38k/16.38k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512 (--/1.18m params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/weights (3x3x256x512, 1.18m/1.18m params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256 (--/294.91k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/weights (3x3x128x256, 294.91k/294.91k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256 (--/294.91k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/weights (3x3x128x256, 294.91k/294.91k params)
#       FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128 (--/73.73k params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/BatchNorm (--/0 params)
#         FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/weights (3x3x64x128, 73.73k/73.73k params)
#
# ======================End of Report==========================
# 137 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*,.*Initializer.*,.*Regularizer.*,.*BiasAdd.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/13.71k flops)
#   MultipleGridAnchorGenerator/mul_20 (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/sub (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/mul_19 (2.17k/2.17k flops)
#   MultipleGridAnchorGenerator/mul_27 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/sub_1 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/mul_28 (1.20k/1.20k flops)
#   MultipleGridAnchorGenerator/mul_21 (1.08k/1.08k flops)
#   MultipleGridAnchorGenerator/mul_29 (600/600 flops)
#   MultipleGridAnchorGenerator/sub_2 (300/300 flops)
#   MultipleGridAnchorGenerator/mul_35 (300/300 flops)
#   MultipleGridAnchorGenerator/mul_36 (300/300 flops)
#   MultipleGridAnchorGenerator/mul_37 (150/150 flops)
#   MultipleGridAnchorGenerator/sub_3 (108/108 flops)
#   MultipleGridAnchorGenerator/mul_44 (108/108 flops)
#   MultipleGridAnchorGenerator/mul_43 (108/108 flops)
#   MultipleGridAnchorGenerator/mul_45 (54/54 flops)
#   MultipleGridAnchorGenerator/sub_4 (48/48 flops)
#   MultipleGridAnchorGenerator/mul_51 (48/48 flops)
#   MultipleGridAnchorGenerator/mul_52 (48/48 flops)
#   MultipleGridAnchorGenerator/mul_53 (24/24 flops)
#   MultipleGridAnchorGenerator/mul_18 (19/19 flops)
#   MultipleGridAnchorGenerator/mul_17 (19/19 flops)
#   MultipleGridAnchorGenerator/mul_60 (12/12 flops)
#   MultipleGridAnchorGenerator/sub_5 (12/12 flops)
#   MultipleGridAnchorGenerator/mul_59 (12/12 flops)
#   MultipleGridAnchorGenerator/mul_25 (10/10 flops)
#   MultipleGridAnchorGenerator/mul_26 (10/10 flops)
#   MultipleGridAnchorGenerator/mul_40 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_30 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_61 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_46 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_47 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_48 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_56 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_55 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_54 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_39 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_38 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_32 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_31 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_24 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_23 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_22 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_19 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_18 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_17 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_16 (6/6 flops)
#   MultipleGridAnchorGenerator/truediv_15 (6/6 flops)
#   MultipleGridAnchorGenerator/mul_34 (5/5 flops)
#   MultipleGridAnchorGenerator/mul_33 (5/5 flops)
#   MultipleGridAnchorGenerator/mul_41 (3/3 flops)
#   MultipleGridAnchorGenerator/truediv_14 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_42 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_14 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_15 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_16 (3/3 flops)
#   MultipleGridAnchorGenerator/mul_49 (2/2 flops)
#   MultipleGridAnchorGenerator/mul_50 (2/2 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField_1/Equal (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/sub_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_8 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_7 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_6 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/SortByField/Equal (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/Greater_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_19 (1/1 flops)
#   Preprocessor/map/while/Less_1 (1/1 flops)
#   Preprocessor/map/while/Less (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/ones/Less (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_8 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_7 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_6 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_5 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_4 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_3 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_18 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_17 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_16 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_15 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_14 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_13 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_12 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_11 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_10 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/PadOrClipBoxList/sub_1 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_4 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_10 (1/1 flops)
#   MultipleGridAnchorGenerator/Minimum (1/1 flops)
#   MultipleGridAnchorGenerator/truediv (1/1 flops)
#   MultipleGridAnchorGenerator/mul_9 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_8 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_7 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_6 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_58 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_57 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_5 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_11 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_3 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_2 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_13 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_12 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_11 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_10 (1/1 flops)
#   MultipleGridAnchorGenerator/mul_1 (1/1 flops)
#   MultipleGridAnchorGenerator/mul (1/1 flops)
#   MultipleGridAnchorGenerator/assert_equal_1/Equal (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_9 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_2 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Greater (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/truediv (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/ChangeCoordinateFrame/sub (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/Less_1 (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/Less (1/1 flops)
#   Postprocessor/BatchMultiClassNonMaxSuppression/map/while/MultiClassNonMaxSuppression/Minimum_3 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_8 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_7 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_6 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_5 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_4 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_3 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_2 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_13 (1/1 flops)
#   MultipleGridAnchorGenerator/truediv_12 (1/1 flops)
#
# ======================End of Report==========================
# 2020-08-10 05:54:05.396915: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-10 05:54:05.431984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.432534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-10 05:54:05.432886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 05:54:05.434814: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 05:54:05.436214: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 05:54:05.436676: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 05:54:05.445068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 05:54:05.446300: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 05:54:05.454741: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 05:54:05.454882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.455478: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.455985: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 05:54:05.456417: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-10 05:54:05.460963: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-08-10 05:54:05.461139: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a6ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 05:54:05.461166: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-10 05:54:05.568424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.569095: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a6ed80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-10 05:54:05.569125: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-08-10 05:54:05.569331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.569862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-10 05:54:05.569929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 05:54:05.569954: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 05:54:05.569978: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 05:54:05.569998: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 05:54:05.570018: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 05:54:05.570037: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 05:54:05.570057: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 05:54:05.570149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.570761: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.571286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 05:54:05.571354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 05:54:05.572537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 05:54:05.572567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 05:54:05.572577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 05:54:05.572707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.573252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:05.573771: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-10 05:54:05.573817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-200000
# I0810 05:54:05.576523 140172771014528 saver.py:1284] Restoring parameters from training/model.ckpt-200000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0810 05:54:07.215939 140172771014528 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2020-08-10 05:54:07.672467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:07.673057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-10 05:54:07.673147: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 05:54:07.673173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 05:54:07.673195: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 05:54:07.673215: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 05:54:07.673236: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 05:54:07.673255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 05:54:07.673276: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 05:54:07.673367: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:07.673924: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:07.674408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 05:54:07.674447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 05:54:07.674460: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 05:54:07.674470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 05:54:07.674561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:07.675111: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:07.675622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-200000
# I0810 05:54:07.677834 140172771014528 saver.py:1284] Restoring parameters from training/model.ckpt-200000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0810 05:54:08.272042 140172771014528 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0810 05:54:08.272288 140172771014528 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 324 variables.
# I0810 05:54:08.589247 140172771014528 graph_util_impl.py:334] Froze 324 variables.
# INFO:tensorflow:Converted 324 variables to const ops.
# I0810 05:54:08.660486 140172771014528 graph_util_impl.py:394] Converted 324 variables to const ops.
# 2020-08-10 05:54:08.818011: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:08.818785: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-08-10 05:54:08.818924: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-10 05:54:08.818961: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-10 05:54:08.818982: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-10 05:54:08.819002: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-10 05:54:08.819021: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-10 05:54:08.819039: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-10 05:54:08.819059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-10 05:54:08.819163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:08.820062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:08.820672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-10 05:54:08.820718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-10 05:54:08.820734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-10 05:54:08.820747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-10 05:54:08.820853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:08.821485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-10 05:54:08.822060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0810 05:54:09.301574 140172771014528 deprecation.py:323] From /gdrive/My Drive/object_detection/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# I0810 05:54:09.302248 140172771014528 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0810 05:54:09.302394 140172771014528 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# I0810 05:54:09.565927 140172771014528 builder_impl.py:425] SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# INFO:tensorflow:Writing pipeline config file to ./fine_tuned_model/pipeline.config
# I0810 05:54:09.591582 140172771014528 config_util.py:254] Writing pipeline config file to ./fine_tuned_model/pipeline.config

# %%
#downloads the frozen model that is needed for inference
# output_directory = 'fine_tuned_model' dir specified above.
files.download(output_directory + '/frozen_inference_graph.pb')

# %%
#downlaod the label map
# we specified 'data_base_url' above. It directs to
# 'object_detection/data/' folder.
files.download(data_base_url + '/label_map.pbtxt')

# %%
#Testing Code
import os
import cv2
import numpy as np
import tensorflow as tf
import sys

sys.path.append("..")

# %%
# Import utilites
# Import utils in the model testing directory 
from utils import label_map_util
from utils import visualization_utils as vis_util

# %%
# Name of the directory containing the object detection module we're using
MODEL_NAME = 'inference_graph'
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'
PATH_TO_LABELS = 'label_map.pbtxt'
IMAGE_NAME = '02827.jpg'
PATH_TO_IMAGE = '02827.jpg'

NUM_CLASSES = 5

# %%
# Load the Tensorflow model into memory.
# Very IMPORTANT - Import tensorflow.compat.v1 as tf
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

# %%
sess = tf.Session(graph=detection_graph)
image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
num_detections = detection_graph.get_tensor_by_name('num_detections:0')
PATH_TO_TEST_IMAGES_DIR = 'test_images'
for i in range(0,5):
    TEST_IMAGE_PATHS = [os.path.join(PATH_TO_TEST_IMAGES_DIR, '{}.jpg'.format(i))]
IMAGE_SIZE = (20,20)

# %%
from PIL import Image

def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)
with detection_graph.as_default():
    for image_path in TEST_IMAGE_PATHS:
        image = Image.open(image_path)
        image_np = load_image_into_numpy_array(image)
        image_np_expanded = np.expand_dims(image_np, axis=0)
        #boxes = detection_graph.get_tensor_by_name('detection_boxes:0')

(boxes, scores, classes, num) = sess.run(
    [detection_boxes, detection_scores, detection_classes, num_detections],
    feed_dict={image_tensor: image_np_expanded})

label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %%
#import necessary packages

from io import StringIO
from collections import defaultdict
from PIL import Image
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
vis_util.visualize_boxes_and_labels_on_image_array(
    image_np,
    np.squeeze(boxes),
    np.squeeze(classes).astype(np.int32),
    np.squeeze(scores),
    category_index,
    use_normalized_coordinates=True,
    line_thickness=8,
    min_score_thresh=0.60)
plt.figure(figsize=IMAGE_SIZE)
plt.imshow(image_np)
plt.show()
#cv2.imshow('Ob', image_np)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
